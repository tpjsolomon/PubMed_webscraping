# %% [markdown]
# # Automated PubMed search for: General info for Veohtu articles

# %% [markdown]
# This script is for enhancing the efficiency of my research method. It automates my literature searches when researching and writing.

# %% [markdown]
# ## Step 1: Specify the intervention(s)

# %%
# Insert the search terms ()"InsertNameOfThing" and "AltNameOfThing"). For example, (nitrate[ti] OR beetroot[ti])
Intervention = "type 2 diabetes[ti]"

# %% [markdown]
# ## Step 2: Run the search

# %%
# Install Biopython package
# See documentation at https://pypi.org/project/biopython/ and https://biopython.org/wiki/Documentation
# and use at https://www.ncbi.nlm.nih.gov/books/NBK25499/
# !pip install biopython
# Import Entrez module from Bio package
from Bio import Entrez
from urllib.parse import quote
# import webbrowser package to automatically open the weblinks
# NOTE removing this because there are too many links in this script!
# import webbrowser

# Insert any email address for PubMed entrez to work
Entrez.email = "anynerd@anymail.com"

# Define search queries
queries = {
    "INCIDENCE, PREVALENCE, OR EPIDEMIOLOGY": f"{Intervention} AND (inciden*[Title] OR prevalen*[Title] OR epidemiol*[Title])",
    "SYSTEMATIC REVIEWS ON INCIDENCE, PREVALENCE, OR EPIDEMIOLOGY": f"{Intervention} AND (inciden*[Title] OR prevalen*[Title] OR epidemiol*[Title]) AND (meta-analysis[pt] OR meta-analysis[ti] OR systematic review[pt] OR systematic review[ti])",
    "RISK FACTORS, CAUSES, PATHOPHYSIOLOGY, AND (A)ETIOLOGY": f"{Intervention} AND (risk[ti] OR cause*[Title] OR pathophys*[Title] OR etiol*[Title] OR aetiol*[Title] OR mechanis*[Title])",
    "NARRATIVE REVIEWS ON RISK FACTORS, CAUSES, PATHOPHYSIOLOGY, AND (A)ETIOLOGY": f"{Intervention} AND (risk[ti] OR cause*[Title] OR pathophys*[Title] OR etiol*[Title] OR aetiol*[Title] OR mechanis*[Title]) AND (review[Filter])",
    "OBSERVATIONAL STUDIES ON RISK FACTORS, CAUSES, PATHOPHYSIOLOGY, AND (A)ETIOLOGY": f"{Intervention} AND (risk[ti] OR cause*[Title] OR pathophys*[Title] OR etiol*[Title] OR aetiol*[Title] OR mechanis*[Title]) AND (observation*[ti] OR cohort[ti] OR relation*[ti] OR correlat*[ti] OR associat*[ti])",
    "REVIEWS OF OBSERVATIONAL STUDIES ON RISK FACTORS, CAUSES, PATHOPHYSIOLOGY, AND (A)ETIOLOGY": f"{Intervention} AND (risk[ti] OR cause*[Title] OR pathophys*[Title] OR etiol*[Title] OR aetiol*[Title] OR mechanis*[Title]) AND (observation*[ti] OR cohort[ti] OR relation*[ti] OR correlat*[ti] OR associat*[ti]) AND (review[filter] OR meta-analysis[ti] OR systematic review[ti])",
    "SYSTEMATIC REVIEWS ON RISK FACTORS, CAUSES, PATHOPHYSIOLOGY, AND (A)ETIOLOGY": f"{Intervention} AND (risk[ti] OR cause*[Title] OR pathophys*[Title] OR etiol*[Title] OR aetiol*[Title] OR mechanis*[Title]) AND (meta-analysis[pt] OR meta-analysis[ti] OR systematic review[pt] OR systematic review[ti])",
    "NARRATIVE REVIEWS ON SIGNS & SYMPTOMS": f"{Intervention} AND (sign*[Title] OR symptom*[Title]) AND (review[Filter])",
    "SYSTEMATIC REVIEWS ON SIGNS & SYMPTOMS": f"{Intervention} AND (sign*[Title] OR symptom*[Title]) AND (meta-analysis[pt] OR meta-analysis[ti] OR systematic review[pt] OR systematic review[ti])",
    "DIAGNOSIS": f"{Intervention} AND diagnos*[Title]",
    "NARRATIVE REVIEWS ON DIAGNOSIS": f"{Intervention} AND diagnos*[Title] AND (review[Filter])",
    "SYSTEMATIC REVIEWS ON DIAGNOSIS": f"{Intervention} AND diagnos*[Title] AND (meta-analysis[pt] OR meta-analysis[ti] OR systematic review[pt] OR systematic review[ti])"
}

# Function to search PubMed
# Note: retmax=100 returns the first 100 results. See https://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.ESearch for details
def search_pubmed(query):
    with Entrez.esearch(db="pubmed", term=query, retmax=100, sort="pub_date") as handle:
        result = Entrez.read(handle)
        return result

# Function to fetch article details from PubMed
def fetch_article_details(pmids):
    details = []
    for pmid in pmids:
        try:
            handle = Entrez.esummary(db="pubmed", id=pmid, retmode="xml")
            records = Entrez.read(handle)
            handle.close()

            if records and len(records) > 0:
                record = records[0]
                title = record.get("Title", "No Title Available")

                pubmed_url = f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/"
                doi = record.get("DOI", "No DOI Available")
                doi_url = f"https://doi.org/{quote(doi)}" if doi != "No DOI Available" else "DOI Not Available"
                scihub_url = f"https://sci-hub.st/{quote(doi)}" if doi != "No DOI Available" else ""

                details.append({
                    "PMID": pmid,
                    "Title": title,
                    "PubMed URL": pubmed_url,
                    "DOI URL": doi_url,
                    "Sci-hub URL": scihub_url
                })
            else:
                print(f"No details found for PMID: {pmid}")

        except Exception as e:
            print(f"An error occurred while fetching details for PMID: {pmid}. Error: {e}")

    return details

# Iterate through each query and execute
for query_name, query in queries.items():
    print(f"\n\n{query_name}:")
    print(query)

    # Run the search
    results = search_pubmed(query)

    # Display search results
    count = int(results['Count'])
    print(f"Search returned {count} results.")

    if count == 0:
        continue  # Skip to the next query if no results are found

    print(f"Article IDs: {results['IdList']}")

    # Assign the IdList of PMIDs to pmids
    pmids = results['IdList']

    # Open the list in PubMed
    base_url = "https://pubmed.ncbi.nlm.nih.gov/?term="
    pmid_string = ",".join(pmids)
    full_url = base_url + pmid_string
    # I removed the following line of code to prevent the links automatically opening!
    # webbrowser.open(full_url)
    print(f"PubMed URL: {full_url}")

    # Fetch article details
    article_details = fetch_article_details(pmids)

    # Output the results
    for article in article_details:
        print(f"○ {article['PubMed URL']} {article['DOI URL']} {article['Sci-hub URL']} {article['Title']}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 26.8 MB/s eta 0:00:00
# ...
#
#
# INCIDENCE, PREVALENCE, OR EPIDEMIOLOGY:
# type 2 diabetes[ti] AND (inciden*[Title] OR prevalen*[Title] OR epidemiol*[Title])
# Search returned 4168 results.
# ...

# %% [markdown]
# ## Then, copy-paste the output above into Google Doc/Word Doc. Note that when copied into Doc, you will have to adjust the font, font color, background color, etc.
