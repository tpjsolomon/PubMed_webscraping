# %% [markdown]
# # Automated PubMed search for: What are the drawbacks of <em>intervention</em>?

# %% [markdown]
# This script is for enhancing the efficiency of my research method. It automates my literature searches when researching and writing.

# %% [markdown]
# ## Step 1: Specify the intervention(s)

# %%
# Insert the search terms ()"InsertNameOfThing" and "AltNameOfThing"). For example, (nitrate[ti] OR beetroot[ti])
Intervention = "(beta-alanine[ti] OR alanine[ti])"

# %% [markdown]
# ## Step 2: Run the search

# %%
# Install Biopython package
# See documentation at https://pypi.org/project/biopython/ and https://biopython.org/wiki/Documentation
# and use at https://www.ncbi.nlm.nih.gov/books/NBK25499/
# !pip install biopython
# Import Entrez module from Bio package
from Bio import Entrez
from urllib.parse import quote
# import webbrowser package to automatically open the weblinks
# NOTE removing this because there are too many links in this script!
# import webbrowser

# Insert any email address for PubMed entrez to work
Entrez.email = "anynerd@anymail.com"

# Define search queries
queries = {
    "All papers on toxicology, adverse effects, side effects, or risk assessment": f"{Intervention} AND (toxic*[ti] OR adverse[ti] OR side effect[ti] OR safety[ti] OR risk assessment[ti])",
    "Narrative reviews on toxicology, adverse effects, side effects, or risk assessment": f"{Intervention} AND (toxic*[ti] OR adverse[ti] OR side effect[ti] OR safety[ti] OR risk assessment[ti]) AND (review[Filter])",
    "All papers on toxicology & adverse effects": f"{Intervention} AND (adverse effect[tiab] OR adverse outcome[tiab])",
    "Narrative reviews on toxicology & adverse effects": f"{Intervention} AND (adverse effect[tiab] OR adverse outcome[tiab]) AND (review[Filter])",
    "Case studies of toxicity": f"{Intervention} AND (case study[ti] OR case report[ti])"
}

# Function to search PubMed
# Note: retmax=100 returns the first 100 results. See https://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.ESearch for details
def search_pubmed(query):
    with Entrez.esearch(db="pubmed", term=query, retmax=100, sort="pub_date") as handle:
        result = Entrez.read(handle)
        return result

# Function to fetch article details from PubMed
def fetch_article_details(pmids):
    details = []
    for pmid in pmids:
        try:
            handle = Entrez.esummary(db="pubmed", id=pmid, retmode="xml")
            records = Entrez.read(handle)
            handle.close()

            if records and len(records) > 0:
                record = records[0]
                title = record.get("Title", "No Title Available")

                pubmed_url = f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/"
                doi = record.get("DOI", "No DOI Available")
                doi_url = f"https://doi.org/{quote(doi)}" if doi != "No DOI Available" else "DOI Not Available"
                scihub_url = f"https://sci-hub.st/{quote(doi)}" if doi != "No DOI Available" else ""

                details.append({
                    "PMID": pmid,
                    "Title": title,
                    "PubMed URL": pubmed_url,
                    "DOI URL": doi_url,
                    "Sci-hub URL": scihub_url
                })
            else:
                print(f"No details found for PMID: {pmid}")

        except Exception as e:
            print(f"An error occurred while fetching details for PMID: {pmid}. Error: {e}")

    return details

# Iterate through each query and execute
for query_name, query in queries.items():
    print(f"\n\n{query_name}:")
    print(query)

    # Run the search
    results = search_pubmed(query)

    # Display search results
    count = int(results['Count'])
    print(f"Search returned {count} results.")

    if count == 0:
        continue  # Skip to the next query if no results are found

    print(f"Article IDs: {results['IdList']}")

    # Assign the IdList of PMIDs to pmids
    pmids = results['IdList']

    # Open the list in PubMed
    base_url = "https://pubmed.ncbi.nlm.nih.gov/?term="
    pmid_string = ",".join(pmids)
    full_url = base_url + pmid_string
    # I removed the following line of code to prevent the links automatically opening!
    # webbrowser.open(full_url)
    print(f"PubMed URL: {full_url}")

    # Fetch article details
    article_details = fetch_article_details(pmids)

    # Output the results
    for article in article_details:
        print(f"○ {article['PubMed URL']} {article['DOI URL']} {article['Sci-hub URL']} {article['Title']}")
# Out:
# Collecting biopython
#   Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.26.4)
# Downloading biopython-1.84-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.84
#
#
# All papers on toxicology, adverse effects, side effects, or risk assessment:
# (beta-alanine[ti] OR alanine[ti]) AND (toxic*[ti] OR adverse[ti] OR side effect[ti] OR safety[ti] OR risk assessment[ti])
# Search returned 72 results.
# Article IDs: ['39120329', '38938614', '38779514', '38417517', '37999510', '36946007', '37644512', '35581529', '35398501', '35342308', '33610631', '33099142', '32961233', '33092276', '32141731', '31591285', '30980348', '30980076', '30189461', '28470567', '29280981', '29230019', '28088213', '27023909', '27051456', '26769963', '27182252', '26925429', '26395456', '26322236', '26073055', '26604922', '25128598', '25073669', '24697258', '24118944', '24164464', '23424646', '24627764', '22836071', '21236519', '22314682', '22158663', '20392940', '20064512', '19247208', '19085960', '19929735', '17971091', '17892268', '17036403', '10770762', '10692560', '9533405', '9029549', '8555405', '7482589', '8526739', '8423703', '8442020', '1469924', '1346985', '2048290', '2900629', '6414438', '7347821', '7452683', '560816', '973222', '5602437', '14222192', '14482906']
# PubMed URL: https://pubmed.ncbi.nlm.nih.gov/?term=39120329,38938614,38779514,38417517,37999510,36946007,37644512,35581529,35398501,35342308,33610631,33099142,32961233,33092276,32141731,31591285,30980348,30980076,30189461,28470567,29280981,29230019,28088213,27023909,27051456,26769963,27182252,26925429,26395456,26322236,26073055,26604922,25128598,25073669,24697258,24118944,24164464,23424646,24627764,22836071,21236519,22314682,22158663,20392940,20064512,19247208,19085960,19929735,17971091,17892268,17036403,10770762,10692560,9533405,9029549,8555405,7482589,8526739,8423703,8442020,1469924,1346985,2048290,2900629,6414438,7347821,7452683,560816,973222,5602437,14222192,14482906
# ○ https://pubmed.ncbi.nlm.nih.gov/39120329/ https://doi.org/10.3390/cells13151300 https://sci-hub.st/10.3390/cells13151300 Overexpression of Toxic Poly(Glycine-Alanine) Aggregates in Primary Neuronal Cultures Induces Time-Dependent Autophagic and Synaptic Alterations but Subtle Activity Impairments.
# ○ https://pubmed.ncbi.nlm.nih.gov/38938614/ https://doi.org/10.7717/peerj.17613 https://sci-hub.st/10.7717/peerj.17613 Evaluation of alanine aminotransferase/aspartate aminotransferase ratio and high-density lipoprotein for predicting neonatal adverse outcomes associated with intrahepatic cholestasis of pregnancy.
# ○ https://pubmed.ncbi.nlm.nih.gov/38779514/ https://doi.org/10.14218/JCTH.2023.00417 https://sci-hub.st/10.14218/JCTH.2023.00417 Five-year Treatment with Tenofovir Alafenamide Achieves High Rates of Viral Suppression, Alanine Aminotransferase Normalization, and Favorable Bone and Renal Safety in Chinese Chronic Hepatitis B Patients.
# ○ https://pubmed.ncbi.nlm.nih.gov/38417517/ https://doi.org/10.1016/j.scitotenv.2024.171255 https://sci-hub.st/10.1016/j.scitotenv.2024.171255 How does the neurotoxin β-N-methylamino-L-alanine exist in biological matrices and cause toxicity?
# ○ https://pubmed.ncbi.nlm.nih.gov/37999510/ https://doi.org/10.3390/toxins15110647 https://sci-hub.st/10.3390/toxins15110647 Effects of the Toxic Non-Protein Amino Acid β-Methylamino-L-Alanine (BMAA) on Intracellular Amino Acid Levels in Neuroblastoma Cells.
# ○ https://pubmed.ncbi.nlm.nih.gov/7347821/ DOI Not Available  [Levels of aspartate aminotransferase and alanine aminotransferase in two factories with various hepato-toxic risks].
# ○ https://pubmed.ncbi.nlm.nih.gov/7452683/ https://doi.org/10.1021/jm00186a007 https://sci-hub.st/10.1021/jm00186a007 Synthetic and preliminary hemodynamic and whole animal toxicity studies on (R,S)-, (R)-, and (S)-2-methyl-3-(2,4,5-trihydroxyphenyl)alanine.
# ○ https://pubmed.ncbi.nlm.nih.gov/560816/ DOI Not Available  Alkaline phosphatase, leucine aminopeptidase, and alanine aminotransferase activities with obstructive and toxic hepatic disease in cats.
# ○ https://pubmed.ncbi.nlm.nih.gov/973222/ https://doi.org/10.1016/0041-008x%2876%2990211-8 https://sci-hub.st/10.1016/0041-008x%2876%2990211-8 Alanine: a toxicity study.
# ○ https://pubmed.ncbi.nlm.nih.gov/5602437/ DOI Not Available  [Sorbitol dehydrogenase, alanine aminotransferase and phosphohexose isomerase in blood plasma of rats with acute toxic liver destruction].
# ○ https://pubmed.ncbi.nlm.nih.gov/14222192/ https://doi.org/10.1016/0006-2952%2864%2990192-3 https://sci-hub.st/10.1016/0006-2952%2864%2990192-3 ENHANCEMENT BY L-GLUTAMATE AND L-ALANINE OF ARGININE PROTECTION AGAINST HYDRAZINE TOXICITY.
# ○ https://pubmed.ncbi.nlm.nih.gov/14482906/ DOI Not Available  Clinical toxicity after graded doses of alanine mustard.
#
#
# Narrative reviews on toxicology, adverse effects, side effects, or risk assessment:
# (beta-alanine[ti] OR alanine[ti]) AND (toxic*[ti] OR adverse[ti] OR side effect[ti] OR safety[ti] OR risk assessment[ti]) AND (review[Filter])
# Search returned 3 results.
# Article IDs: ['38417517', '24697258', '2048290']
# PubMed URL: https://pubmed.ncbi.nlm.nih.gov/?term=38417517,24697258,2048290
# ○ https://pubmed.ncbi.nlm.nih.gov/38417517/ https://doi.org/10.1016/j.scitotenv.2024.171255 https://sci-hub.st/10.1016/j.scitotenv.2024.171255 How does the neurotoxin β-N-methylamino-L-alanine exist in biological matrices and cause toxicity?
# ○ https://pubmed.ncbi.nlm.nih.gov/24697258/ https://doi.org/10.1111/nure.12087 https://sci-hub.st/10.1111/nure.12087 Evidence-based evaluation of potential benefits and safety of beta-alanine supplementation for military personnel.
# ○ https://pubmed.ncbi.nlm.nih.gov/2048290/ https://doi.org/10.1007/BF00497793 https://sci-hub.st/10.1007/BF00497793 The toxicological significance of decreased activities of blood alanine and aspartate aminotransferase.
#
#
# All papers on toxicology & adverse effects:
# (beta-alanine[ti] OR alanine[ti]) AND (adverse effect[tiab] OR adverse outcome[tiab])
# Search returned 11 results.
# Article IDs: ['38436510', '36946007', '32432779', '31094112', '26604922', '18986100', '18968259', '9434117', '8588953', '7720763', '2007961']
# PubMed URL: https://pubmed.ncbi.nlm.nih.gov/?term=38436510,36946007,32432779,31094112,26604922,18986100,18968259,9434117,8588953,7720763,2007961
# ○ https://pubmed.ncbi.nlm.nih.gov/38436510/ https://doi.org/10.1002/jcph.2422 https://sci-hub.st/10.1002/jcph.2422 Changing Trajectories of Alanine Aminotransferase and Risk of Antituberculosis Drug-Induced Liver Injury in Chinese Patients: A Cohort Study.
# ○ https://pubmed.ncbi.nlm.nih.gov/36946007/ https://doi.org/10.1002/jat.4468 https://sci-hub.st/10.1002/jat.4468 A 90-day toxicity study of tripeptide, arginine-alanine-lysine.
# ○ https://pubmed.ncbi.nlm.nih.gov/32432779/ https://doi.org/10.26355/eurrev_202005_21209 https://sci-hub.st/10.26355/eurrev_202005_21209 Women dealing with hot flushes: the role of β-alanine.
# ○ https://pubmed.ncbi.nlm.nih.gov/31094112/ DOI Not Available  Efficacy Of Interrupted And Modified Deferasirox Dose Among Paediatric Patients With Β- Thalassemia Major And High Alanine Aminotransferase Level.
# ○ https://pubmed.ncbi.nlm.nih.gov/26604922/ https://doi.org/10.1155/2015/739746 https://sci-hub.st/10.1155/2015/739746 Acute β-N-Methylamino-L-alanine Toxicity in a Mouse Model.
# ○ https://pubmed.ncbi.nlm.nih.gov/18986100/ https://doi.org/10.1080/09674845.2008.11732816 https://sci-hub.st/10.1080/09674845.2008.11732816 Influence of stable, long-term treatment with phenobarbital on the activity of serum alanine aminotransferase and gamma-glutamyltransferase.
# ○ https://pubmed.ncbi.nlm.nih.gov/18968259/ https://doi.org/10.1016/s0039-9140%2800%2900675-5 https://sci-hub.st/10.1016/s0039-9140%2800%2900675-5 A chemically modified carbon paste electrode with d-lactate dehydrogenase and alanine aminotranferase enzyme sequences for d-lactic acid analysis.
# ○ https://pubmed.ncbi.nlm.nih.gov/9434117/ https://doi.org/10.1016/s0167-4838%2897%2900129-5 https://sci-hub.st/10.1016/s0167-4838%2897%2900129-5 Effect of selective cysteine --> alanine replacements on the catalytic functions of lysine: N6-hydroxylase.
# ○ https://pubmed.ncbi.nlm.nih.gov/8588953/ https://doi.org/10.1177/096032719501401109 https://sci-hub.st/10.1177/096032719501401109 Pharmacokinetic, pharmacodynamic, and pharmacotoxic profiles of recombinant-methionyl human interleukin-2[alanine-125] (r-metHuIL-2[ala-125]) following intravenous and subcutaneous administration in rats.
# ○ https://pubmed.ncbi.nlm.nih.gov/7720763/ https://doi.org/10.1007/BF00196855 https://sci-hub.st/10.1007/BF00196855 Upper limit of plasma alanine amino transferase during phase I studies.
# ○ https://pubmed.ncbi.nlm.nih.gov/2007961/ https://doi.org/10.1016/s0022-3476%2805%2981432-5 https://sci-hub.st/10.1016/s0022-3476%2805%2981432-5 Alanine-based oral rehydration therapy for infants with acute diarrhea.
#
#
# Narrative reviews on toxicology & adverse effects:
# (beta-alanine[ti] OR alanine[ti]) AND (adverse effect[tiab] OR adverse outcome[tiab]) AND (review[Filter])
# Search returned 1 results.
# Article IDs: ['32432779']
# PubMed URL: https://pubmed.ncbi.nlm.nih.gov/?term=32432779
# ○ https://pubmed.ncbi.nlm.nih.gov/32432779/ https://doi.org/10.26355/eurrev_202005_21209 https://sci-hub.st/10.26355/eurrev_202005_21209 Women dealing with hot flushes: the role of β-alanine.
#
#
# Case studies of toxicity:
# (beta-alanine[ti] OR alanine[ti]) AND (case study[ti] OR case report[ti])
# Search returned 13 results.
# Article IDs: ['38825401', '36399392', '35346323', '31970040', '30694660', '28204939', '24753338', '21456693', '20060816', '20397675', '20361773', '17994855', '9641644']
# PubMed URL: https://pubmed.ncbi.nlm.nih.gov/?term=38825401,36399392,35346323,31970040,30694660,28204939,24753338,21456693,20060816,20397675,20361773,17994855,9641644
# ○ https://pubmed.ncbi.nlm.nih.gov/38825401/ https://doi.org/10.1016/j.transproceed.2024.04.025 https://sci-hub.st/10.1016/j.transproceed.2024.04.025 Abnormally Low Alanine Aminotransferase Ameliorated by a Living Donor Liver Transplantation: A Case Report.
# ○ https://pubmed.ncbi.nlm.nih.gov/36399392/ https://doi.org/10.1097/SGA.0000000000000697 https://sci-hub.st/10.1097/SGA.0000000000000697 CLINICAL CURE OF A CHRONIC HEPATITIS B PATIENT WITH NORMAL SERUM ALANINE AMINOTRANSFERASE TREATED WITH PEGYLATED INTERFERON ALFA-2A: A CASE REPORT.
# ○ https://pubmed.ncbi.nlm.nih.gov/35346323/ https://doi.org/10.1186/s13052-022-01249-y https://sci-hub.st/10.1186/s13052-022-01249-y L-alanine supplementation in Pompe disease (IOPD): a potential therapeutic implementation for patients on ERT? A case report.
# ○ https://pubmed.ncbi.nlm.nih.gov/31970040/ https://doi.org/10.7759/cureus.6411 https://sci-hub.st/10.7759/cureus.6411 Mesenteric Panniculitis with Raised Alanine Transaminase Levels: A Rare Case Report from Pakistan.
# ○ https://pubmed.ncbi.nlm.nih.gov/30694660/ https://doi.org/10.1021/acs.jcim.8b00926 https://sci-hub.st/10.1021/acs.jcim.8b00926 Alanine Scanning Effects on the Biochemical and Biophysical Properties of Intrinsically Disordered Proteins: A Case Study of the Histidine to Alanine Mutations in Amyloid-β(42).
# ○ https://pubmed.ncbi.nlm.nih.gov/28204939/ https://doi.org/10.1007/s00894-017-3265-4 https://sci-hub.st/10.1007/s00894-017-3265-4 Metadynamics combined with auxiliary density functional and density functional tight-binding methods: alanine dipeptide as a case study.
# ○ https://pubmed.ncbi.nlm.nih.gov/24753338/ https://doi.org/10.1002/pro.2481 https://sci-hub.st/10.1002/pro.2481 Intrinsic α-helical and β-sheet conformational preferences: a computational case study of alanine.
# ○ https://pubmed.ncbi.nlm.nih.gov/21456693/ https://doi.org/10.1063/1.3571453 https://sci-hub.st/10.1063/1.3571453 Strong water-mediated friction asymmetry and surface dynamics of zwitterionic solids at ambient conditions: L-alanine as a case study.
# ○ https://pubmed.ncbi.nlm.nih.gov/20060816/ https://doi.org/10.1016/j.cbi.2010.01.003 https://sci-hub.st/10.1016/j.cbi.2010.01.003 Alanine-to-threonine substitutions and amyloid diseases: butyrylcholinesterase as a case study.
# ○ https://pubmed.ncbi.nlm.nih.gov/20397675/ https://doi.org/10.1021/jp100114v https://sci-hub.st/10.1021/jp100114v Molecular level characterization of the inorganic-bioorganic interface by solid state NMR: alanine on a silica surface, a case study.
# ○ https://pubmed.ncbi.nlm.nih.gov/20361773/ https://doi.org/10.1021/jp100950w https://sci-hub.st/10.1021/jp100950w Metadynamics as a tool for mapping the conformational and free-energy space of peptides--the alanine dipeptide case study.
# ○ https://pubmed.ncbi.nlm.nih.gov/17994855/ https://doi.org/10.1063/1.2794763 https://sci-hub.st/10.1063/1.2794763 Estimating kinetic rates from accelerated molecular dynamics simulations: alanine dipeptide in explicit solvent as a case study.
# ○ https://pubmed.ncbi.nlm.nih.gov/9641644/ https://doi.org/10.1111/j.1440-1746.1998.tb00672.x https://sci-hub.st/10.1111/j.1440-1746.1998.tb00672.x Case report: Alanine aminotransferase deficiency detected in a patient with chronic hepatitis C.

# %% [markdown]
# ## Then, copy-paste the output above into Google Doc/Word Doc. Note that when copied into Doc, you will have to adjust the font, font color, background color, etc.
